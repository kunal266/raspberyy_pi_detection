# %% [markdown]
# ## Kunal Makwana<br>19BAI1011<br>CSE4038<br>EX3

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
img0 = cv2.imread('/content/eye.png')

gray = cv2.cvtColor(img0, cv2.COLOR_BGR2GRAY)
img_gaussian = cv2.GaussianBlur(gray,(3,3),0)

img = cv2.GaussianBlur(gray,(3,3),0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y
edges = cv2.Canny(img,100,200)
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img_gaussian, -1, kernelx)
img_prewitty = cv2.filter2D(img_gaussian, -1, kernely)


cv2_imshow(img)

cv2_imshow(laplacian)
cv2_imshow(sobelx)
cv2_imshow(sobely)
cv2_imshow(edges)
cv2_imshow(img_prewittx)
cv2_imshow(img_prewitty)
# Out:
# <PIL.Image.Image image mode=L size=565x584 at 0x7FB239FAE450>
# <PIL.Image.Image image mode=L size=565x584 at 0x7FB239FAEBD0>
# <PIL.Image.Image image mode=L size=565x584 at 0x7FB239FAEBD0>
# <PIL.Image.Image image mode=L size=565x584 at 0x7FB239FAE550>
# <PIL.Image.Image image mode=L size=565x584 at 0x7FB239FAEBD0>
# <PIL.Image.Image image mode=L size=565x584 at 0x7FB239FAE450>
# <PIL.Image.Image image mode=L size=565x584 at 0x7FB239FAEE50>
